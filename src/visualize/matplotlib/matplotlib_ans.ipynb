# %% [markdown]
# #### Iris 데이터셋을 활용한 시각화 해보기

# %% [markdown]
# #### 목표 : 다양한 plot, 색상 변경, grid, legend, label등을 사용해 보자

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import cv2 as cv

# %%
data_path = "C:/Users/line/Desktop/brand_new_learn_py/data/csv/setosa/IRIS.csv"

# %%
data = pd.read_csv(data_path)

# %%
data.shape
# Out:
# (150, 5)

# %%
data.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %%
length = data['sepal_length']

# %% [markdown]
# ### figsize = figurebox의 크기를 설정합니다

# %%
plt.figure(figsize=(6,6))
plt.boxplot(length)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2bf14b328b0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x2bf14b32df0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x2bf14b32610>],
#  'medians': [<matplotlib.lines.Line2D at 0x2bf14b4b370>],
#  'fliers': [<matplotlib.lines.Line2D at 0x2bf14b4b610>],
#  'means': []}

# %%
plt.plot(length)

# %%
plt.figure(figsize=(6,6))
plt.xlabel("count")
plt.ylabel("y")
plt.grid()
plt.legend
plt.plot(length)
